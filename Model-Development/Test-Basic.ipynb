# %%
import ModelTrain
import pickle
from time import sleep

histories = list()

import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
# Out:
# 2023-06-03 15:02:35.322088: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-06-03 15:02:35.803098: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# TODO
# * Make 50 class model and 11 class, class parameter. and fix code to transform parameter
# * Test basicCNN
# * Turn on and Off normalization
# * Turn on and Off Dropout(0.1)
# * Make so we can utilize image filters and turn them on and off
# * Make so we can equalize classes and un-equalize classes turn on and off
# * Import 5 other architecutres [Working]
# * Test other architectures
# * Tune other architectures for class 11
# * Tune other architectures for class 50.

# %% [markdown]
# ## ResNet-ImageNetTuning

# %%
# iterations = 0
# for lr in [.001, .0001, .00001]:
#     for im_size in [250, 500]:
#         for batch_size in [16, 32]:
#             tm = ModelTrain.TrainModel(architecture="ResNet50", 
#                                        batch_size=batch_size, 
#                                        image_size=im_size, 
#                                        validation_split=.2, 
#                                        learning_rate=lr, 
#                                        seed_n=1, 
#                                        verbose=0) 
#             history = tm.train()
#             histories.append(history)
#             # File path for the pickle file
#             file_path = "histories.pkl"

#             # Save the list as a pickle file
#             with open(file_path, "wb") as pickle_file:
#                 pickle.dump(histories, pickle_file)
#             # aves this as a pickle, each time to control for unintenioned kernel crashes.
#             iterations += 1
            
#             # Prevent GPU from overheating.
#             if iterations == 4:
#                 iterations = 0
#                 sleep(60*5)

# %% [markdown]
# # Testing BasicCNN

# %%
tm = ModelTrain.TrainModel(architecture="BasicCNN", batch_size=32, image_size=225, validation_split=.2, learning_rate=0.0001, seed_n=1, verbose=1) # Initializing Class
history = tm.train()
histories.append(history)
# Out:
# Found 3181 images belonging to 11 classes.
# Found 790 images belonging to 11 classes.
# 2023-06-03 15:02:36.424616: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-03 15:02:36.440647: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# ...

# %%
import matplotlib.pyplot as plt
def plot_training(history):
    acc = history['accuracy']
    val_acc = history['val_accuracy']
    loss = history['loss']
    val_loss = history['val_loss']
    epochs = range(len(acc))

    fig, axes = plt.subplots(1, 2, figsize=(15,5))
    
    axes[0].plot(epochs, acc, 'r-', label='Training Accuracy')
    axes[0].plot(epochs, val_acc, 'b--', label='Validation Accuracy')
    axes[0].set_title('Training and Validation Accuracy')
    axes[0].legend(loc='best')

    axes[1].plot(epochs, loss, 'r-', label='Training Loss')
    axes[1].plot(epochs, val_loss, 'b--', label='Validation Loss')
    axes[1].set_title('Training and Validation Loss')
    axes[1].legend(loc='best')
    
    plt.show()
    
plot_training(history)

# %%
# File path for the pickle file
file_path = "histories.pkl"

# Save the list as a pickle file
with open(file_path, "wb") as pickle_file:
    pickle.dump(histories, pickle_file)
